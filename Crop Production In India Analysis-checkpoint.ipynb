# %% [markdown]
# <img src='https://plus.unsplash.com/premium_photo-1722899516572-409bf979e5d6?q=80&w=1958&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D' width="1200" height="100">

# %% [markdown]
# # Project - Crop Production In India Analysis

# %% [markdown]
# # Implemented By Sneha Ajaykumar Shukla

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# #### This analysis utilizes a dataset with state name, district name, crop year, season, area, and production to identify trends and disparities in crop production across India, aiming to enhance agricultural efficiency and inform policy decisions.

# %% [markdown]
# ## Objective

# %% [markdown]
# #### 1) Trend Identification: Analyze production trends over time across states and districts.
#
# #### 2) Regional Comparison: Evaluate crop performance by area and production in different regions.
#
# #### 3) Seasonal Analysis: Examine seasonal variations in crop yields.
#
# #### 4) Efficiency Assessment: Assess the relationship between area cultivated and production levels to identify inefficiencies.

# %% [markdown]
# ## Understanding Variables
#
# **State_Name :** Name of States producing crop in india
#
# **District_Name :** Name of Districts producing crop in india
#
# **Crop_Year :** From 1997 to 2015 years are available
#
# **Season :** Name of season in which crops are produced
#
# **Crop :** Different crops produced in India
#
# **Area :** Area in which crop is produced
#
# **Production :** Production of crops are given

# %% [markdown]
# ## GitHub Link

# %% [markdown]
# https://github.com/SnehaShukla14/Sprint_1_Project

# %%
# Installing the packages
# !pip install pandas
# !pip install matplotlib
# !pip install numpy
# !pip install seaborn
# !pip install sidetable
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\sneha\appdata\roaming\python\python310\site-packages (from pandas) (1.22.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\sneha\appdata\roaming\python\python310\site-packages (from matplotlib) (1.22.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\sneha\appdata\roaming\python\python310\site-packages (1.22.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\programdata\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: pandas>=0.25 in c:\programdata\anaconda3\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\sneha\appdata\roaming\python\python310\site-packages (from seaborn) (1.22.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\programdata\anaconda3\lib\site-packages (from seaborn) (3.7.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (22.0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sidetable in c:\users\sneha\appdata\roaming\python\python310\site-packages (0.9.1)
# Requirement already satisfied: pandas>=1.0 in c:\programdata\anaconda3\lib\site-packages (from sidetable) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.0->sidetable) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.0->sidetable) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\sneha\appdata\roaming\python\python310\site-packages (from pandas>=1.0->sidetable) (1.22.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.0->sidetable) (1.16.0)

# %% [markdown]
# **Insight**: Installed all necessary packages

# %% [markdown]
# # Import Necessary Packages

# %%
# Importing the necessary packages for data manipulation and visualisation
import pandas as pd   # Data Manipulation
import matplotlib.pyplot as plt    # Data Visualisation
import numpy as np     # Mathematical Calculation
import seaborn as sns   # powerful Python library for data visualization based on matplotlib
import plotly.express as px   # provides functions to visualize a variety of types of data
import sidetable as stb  # it is a Python library designed to extend pandas’ functionality with additional table

# %% [markdown]
# **Insight**: Imported all necessary packages

# %% [markdown]
# # Loading the files from the local system to the notebook

# %%
# Correctly specify the file path
file_path = r'C:\Users\Sneha\OneDrive\Documents\crop_production.csv'

# Load the dataset
crops = pd.read_csv(file_path)   # Function to read the CSV file from the File path
crops
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# 1       Other Kharif pulses       2.0         1.0
# 2                      Rice     102.0       321.0
# 3                    Banana     176.0       641.0
# 4                 Cashewnut     720.0       165.0
# ...                     ...       ...         ...
# 246086                 Rice     306.0       801.0
# 246087              Sesamum     627.0       463.0
# 246088            Sugarcane     324.0     16250.0
# 246089                 Rice  279151.0    597899.0
# 246090              Sesamum     175.0        88.0
#
# [246091 rows x 7 columns]

# %% [markdown]
# **Insight:** Loading the file from local system to jupyter notebook

# %%
# Prints the shape i.e. the row size by column size of the dataset
crops.shape
# Out:
# (246091, 7)

# %% [markdown]
# **Insight:** Here we print row and column size of the dataset

# %% [markdown]
# # Dataset View

# %%
# Prints the first 5 rows of the dataset
crops.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %% [markdown]
# **Insight**: Here we print first five rows of the dataset.

# %%
# Prints the last 5 rows of the dataset
crops.tail()
# Out:
#          State_Name District_Name  Crop_Year       Season       Crop  \
# 246086  West Bengal       PURULIA       2014  Summer            Rice
# 246087  West Bengal       PURULIA       2014  Summer         Sesamum
# 246088  West Bengal       PURULIA       2014  Whole Year   Sugarcane
# 246089  West Bengal       PURULIA       2014  Winter            Rice
# 246090  West Bengal       PURULIA       2014  Winter         Sesamum
#
#             Area  Production
# 246086     306.0       801.0
# 246087     627.0       463.0
# 246088     324.0     16250.0
# 246089  279151.0    597899.0
# 246090     175.0        88.0

# %% [markdown]
# **Insight**: Here we print last five rows of the dataset

# %%
# To print the column names present in the dataset.
crops.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area',
#        'Production'],
#       dtype='object')

# %% [markdown]
# **Insight**: Print the column name present in the dataset

# %% [markdown]
# # Dataset Information

# %%
# Gives the a concise summary of a DataFrame.
crops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %% [markdown]
# **Insight**: We use info() to get concise summary of our dataset i.e column, non null , count , memory usage and datatype.

# %%
# It provides the season present in the dataset
season = crops['Season'].unique()
print(season)
print("Numbers of Seasons for which dataset is availabe are: ", len(season))
# Out:
# ['Kharif     ' 'Whole Year ' 'Autumn     ' 'Rabi       ' 'Summer     '
#  'Winter     ']
# Numbers of Seasons for which dataset is availabe are:  6

# %% [markdown]
# **Insight:** Season's are displayed through unique values

# %%
# Prints the names and the length of the districts
districts = crops['District_Name'].unique()
print(districts)

print('''
============================================================================================
''')

print("Numbers of districts for which dataset is availabe are: ", len(districts))
# Out:
# ['NICOBARS' 'NORTH AND MIDDLE ANDAMAN' 'SOUTH ANDAMANS' 'ANANTAPUR'
#  'CHITTOOR' 'EAST GODAVARI' 'GUNTUR' 'KADAPA' 'KRISHNA' 'KURNOOL'
#  'PRAKASAM' 'SPSR NELLORE' 'SRIKAKULAM' 'VISAKHAPATANAM' 'VIZIANAGARAM'
#  'WEST GODAVARI' 'ANJAW' 'CHANGLANG' 'DIBANG VALLEY' 'EAST KAMENG'
#  'EAST SIANG' 'KURUNG KUMEY' 'LOHIT' 'LONGDING' 'LOWER DIBANG VALLEY'
#  'LOWER SUBANSIRI' 'NAMSAI' 'PAPUM PARE' 'TAWANG' 'TIRAP' 'UPPER SIANG'
#  'UPPER SUBANSIRI' 'WEST KAMENG' 'WEST SIANG' 'BAKSA' 'BARPETA'
#  'BONGAIGAON' 'CACHAR' 'CHIRANG' 'DARRANG' 'DHEMAJI' 'DHUBRI' 'DIBRUGARH'
#  'DIMA HASAO' 'GOALPARA' 'GOLAGHAT' 'HAILAKANDI' 'JORHAT' 'KAMRUP'
#  'KAMRUP METRO' 'KARBI ANGLONG' 'KARIMGANJ' 'KOKRAJHAR' 'LAKHIMPUR'
#  'MARIGAON' 'NAGAON' 'NALBARI' 'SIVASAGAR' 'SONITPUR' 'TINSUKIA'
#  'UDALGURI' 'ARARIA' 'ARWAL' 'AURANGABAD' 'BANKA' 'BEGUSARAI' 'BHAGALPUR'
#  'BHOJPUR' 'BUXAR' 'DARBHANGA' 'GAYA' 'GOPALGANJ' 'JAMUI' 'JEHANABAD'
#  'KAIMUR (BHABUA)' 'KATIHAR' 'KHAGARIA' 'KISHANGANJ' 'LAKHISARAI'
#  'MADHEPURA' 'MADHUBANI' 'MUNGER' 'MUZAFFARPUR' 'NALANDA' 'NAWADA'
#  'PASHCHIM CHAMPARAN' 'PATNA' 'PURBI CHAMPARAN' 'PURNIA' 'ROHTAS'
#  'SAHARSA' 'SAMASTIPUR' 'SARAN' 'SHEIKHPURA' 'SHEOHAR' 'SITAMARHI' 'SIWAN'
#  'SUPAUL' 'VAISHALI' 'CHANDIGARH' 'BALOD' 'BALODA BAZAR' 'BALRAMPUR'
#  'BASTAR' 'BEMETARA' 'BIJAPUR' 'BILASPUR' 'DANTEWADA' 'DHAMTARI' 'DURG'
#  'GARIYABAND' 'JANJGIR-CHAMPA' 'JASHPUR' 'KABIRDHAM' 'KANKER' 'KONDAGAON'
#  'KORBA' 'KOREA' 'MAHASAMUND' 'MUNGELI' 'NARAYANPUR' 'RAIGARH' 'RAIPUR'
#  'RAJNANDGAON' 'SUKMA' 'SURAJPUR' 'SURGUJA' 'DADRA AND NAGAR HAVELI'
#  'NORTH GOA' 'SOUTH GOA' 'AHMADABAD' 'AMRELI' 'ANAND' 'BANAS KANTHA'
#  'BHARUCH' 'BHAVNAGAR' 'DANG' 'DOHAD' 'GANDHINAGAR' 'JAMNAGAR' 'JUNAGADH'
#  'KACHCHH' 'KHEDA' 'MAHESANA' 'NARMADA' 'NAVSARI' 'PANCH MAHALS' 'PATAN'
#  'PORBANDAR' 'RAJKOT' 'SABAR KANTHA' 'SURAT' 'SURENDRANAGAR' 'TAPI'
#  'VADODARA' 'VALSAD' 'AMBALA' 'BHIWANI' 'FARIDABAD' 'FATEHABAD' 'GURGAON'
#  'HISAR' 'JHAJJAR' 'JIND' 'KAITHAL' 'KARNAL' 'KURUKSHETRA' 'MAHENDRAGARH'
#  'MEWAT' 'PALWAL' 'PANCHKULA' 'PANIPAT' 'REWARI' 'ROHTAK' 'SIRSA'
#  'SONIPAT' 'YAMUNANAGAR' 'CHAMBA' 'HAMIRPUR' 'KANGRA' 'KINNAUR' 'KULLU'
#  'LAHUL AND SPITI' 'MANDI' 'SHIMLA' 'SIRMAUR' 'SOLAN' 'UNA' 'ANANTNAG'
#  'BADGAM' 'BANDIPORA' 'BARAMULLA' 'DODA' 'GANDERBAL' 'JAMMU' 'KARGIL'
#  'KATHUA' 'KISHTWAR' 'KULGAM' 'KUPWARA' 'LEH LADAKH' 'POONCH' 'PULWAMA'
#  'RAJAURI' 'RAMBAN' 'REASI' 'SAMBA' 'SHOPIAN' 'SRINAGAR' 'UDHAMPUR'
#  'BOKARO' 'CHATRA' 'DEOGHAR' 'DHANBAD' 'DUMKA' 'EAST SINGHBUM' 'GARHWA'
#  'GIRIDIH' 'GODDA' 'GUMLA' 'HAZARIBAGH' 'JAMTARA' 'KHUNTI' 'KODERMA'
#  'LATEHAR' 'LOHARDAGA' 'PAKUR' 'PALAMU' 'RAMGARH' 'RANCHI' 'SAHEBGANJ'
#  'SARAIKELA KHARSAWAN' 'SIMDEGA' 'WEST SINGHBHUM' 'BAGALKOT'
#  'BANGALORE RURAL' 'BELGAUM' 'BELLARY' 'BENGALURU URBAN' 'BIDAR'
#  'CHAMARAJANAGAR' 'CHIKBALLAPUR' 'CHIKMAGALUR' 'CHITRADURGA'
#  'DAKSHIN KANNAD' 'DAVANGERE' 'DHARWAD' 'GADAG' 'GULBARGA' 'HASSAN'
#  'HAVERI' 'KODAGU' 'KOLAR' 'KOPPAL' 'MANDYA' 'MYSORE' 'RAICHUR'
#  'RAMANAGARA' 'SHIMOGA' 'TUMKUR' 'UDUPI' 'UTTAR KANNAD' 'YADGIR'
#  'ALAPPUZHA' 'ERNAKULAM' 'IDUKKI' 'KANNUR' 'KASARAGOD' 'KOLLAM' 'KOTTAYAM'
#  'KOZHIKODE' 'MALAPPURAM' 'PALAKKAD' 'PATHANAMTHITTA' 'THIRUVANANTHAPURAM'
#  'THRISSUR' 'WAYANAD' 'AGAR MALWA' 'ALIRAJPUR' 'ANUPPUR' 'ASHOKNAGAR'
#  'BALAGHAT' 'BARWANI' 'BETUL' 'BHIND' 'BHOPAL' 'BURHANPUR' 'CHHATARPUR'
#  'CHHINDWARA' 'DAMOH' 'DATIA' 'DEWAS' 'DHAR' 'DINDORI' 'GUNA' 'GWALIOR'
#  'HARDA' 'HOSHANGABAD' 'INDORE' 'JABALPUR' 'JHABUA' 'KATNI' 'KHANDWA'
#  'KHARGONE' 'MANDLA' 'MANDSAUR' 'MORENA' 'NARSINGHPUR' 'NEEMUCH' 'PANNA'
#  'RAISEN' 'RAJGARH' 'RATLAM' 'REWA' 'SAGAR' 'SATNA' 'SEHORE' 'SEONI'
#  'SHAHDOL' 'SHAJAPUR' 'SHEOPUR' 'SHIVPURI' 'SIDHI' 'SINGRAULI' 'TIKAMGARH'
#  'UJJAIN' 'UMARIA' 'VIDISHA' 'AHMEDNAGAR' 'AKOLA' 'AMRAVATI' 'BEED'
#  'BHANDARA' 'BULDHANA' 'CHANDRAPUR' 'DHULE' 'GADCHIROLI' 'GONDIA'
#  'HINGOLI' 'JALGAON' 'JALNA' 'KOLHAPUR' 'LATUR' 'MUMBAI' 'NAGPUR' 'NANDED'
#  'NANDURBAR' 'NASHIK' 'OSMANABAD' 'PALGHAR' 'PARBHANI' 'PUNE' 'RAIGAD'
#  'RATNAGIRI' 'SANGLI' 'SATARA' 'SINDHUDURG' 'SOLAPUR' 'THANE' 'WARDHA'
#  'WASHIM' 'YAVATMAL' 'BISHNUPUR' 'CHANDEL' 'CHURACHANDPUR' 'IMPHAL EAST'
#  'IMPHAL WEST' 'SENAPATI' 'TAMENGLONG' 'THOUBAL' 'UKHRUL'
#  'EAST GARO HILLS' 'EAST JAINTIA HILLS' 'EAST KHASI HILLS'
#  'NORTH GARO HILLS' 'RI BHOI' 'SOUTH GARO HILLS' 'SOUTH WEST GARO HILLS'
#  'SOUTH WEST KHASI HILLS' 'WEST GARO HILLS' 'WEST JAINTIA HILLS'
#  'WEST KHASI HILLS' 'AIZAWL' 'CHAMPHAI' 'KOLASIB' 'LAWNGTLAI' 'LUNGLEI'
#  'MAMIT' 'SAIHA' 'SERCHHIP' 'DIMAPUR' 'KIPHIRE' 'KOHIMA' 'LONGLENG'
#  'MOKOKCHUNG' 'MON' 'PEREN' 'PHEK' 'TUENSANG' 'WOKHA' 'ZUNHEBOTO' 'ANUGUL'
#  'BALANGIR' 'BALESHWAR' 'BARGARH' 'BHADRAK' 'BOUDH' 'CUTTACK' 'DEOGARH'
#  'DHENKANAL' 'GAJAPATI' 'GANJAM' 'JAGATSINGHAPUR' 'JAJAPUR' 'JHARSUGUDA'
#  'KALAHANDI' 'KANDHAMAL' 'KENDRAPARA' 'KENDUJHAR' 'KHORDHA' 'KORAPUT'
#  'MALKANGIRI' 'MAYURBHANJ' 'NABARANGPUR' 'NAYAGARH' 'NUAPADA' 'PURI'
#  'RAYAGADA' 'SAMBALPUR' 'SONEPUR' 'SUNDARGARH' 'KARAIKAL' 'MAHE'
#  'PONDICHERRY' 'YANAM' 'AMRITSAR' 'BARNALA' 'BATHINDA' 'FARIDKOT'
#  'FATEHGARH SAHIB' 'FAZILKA' 'FIROZEPUR' 'GURDASPUR' 'HOSHIARPUR'
#  'JALANDHAR' 'KAPURTHALA' 'LUDHIANA' 'MANSA' 'MOGA' 'MUKTSAR' 'NAWANSHAHR'
#  'PATHANKOT' 'PATIALA' 'RUPNAGAR' 'S.A.S NAGAR' 'SANGRUR' 'TARN TARAN'
#  'AJMER' 'ALWAR' 'BANSWARA' 'BARAN' 'BARMER' 'BHARATPUR' 'BHILWARA'
#  'BIKANER' 'BUNDI' 'CHITTORGARH' 'CHURU' 'DAUSA' 'DHOLPUR' 'DUNGARPUR'
#  'GANGANAGAR' 'HANUMANGARH' 'JAIPUR' 'JAISALMER' 'JALORE' 'JHALAWAR'
#  'JHUNJHUNU' 'JODHPUR' 'KARAULI' 'KOTA' 'NAGAUR' 'PALI' 'PRATAPGARH'
#  'RAJSAMAND' 'SAWAI MADHOPUR' 'SIKAR' 'SIROHI' 'TONK' 'UDAIPUR'
#  'EAST DISTRICT' 'NORTH DISTRICT' 'SOUTH DISTRICT' 'WEST DISTRICT'
#  'ARIYALUR' 'COIMBATORE' 'CUDDALORE' 'DHARMAPURI' 'DINDIGUL' 'ERODE'
#  'KANCHIPURAM' 'KANNIYAKUMARI' 'KARUR' 'KRISHNAGIRI' 'MADURAI'
#  'NAGAPATTINAM' 'NAMAKKAL' 'PERAMBALUR' 'PUDUKKOTTAI' 'RAMANATHAPURAM'
#  'SALEM' 'SIVAGANGA' 'THANJAVUR' 'THE NILGIRIS' 'THENI' 'THIRUVALLUR'
#  'THIRUVARUR' 'TIRUCHIRAPPALLI' 'TIRUNELVELI' 'TIRUPPUR' 'TIRUVANNAMALAI'
#  'TUTICORIN' 'VELLORE' 'VILLUPURAM' 'VIRUDHUNAGAR' 'ADILABAD' 'HYDERABAD'
#  'KARIMNAGAR' 'KHAMMAM' 'MAHBUBNAGAR' 'MEDAK' 'NALGONDA' 'NIZAMABAD'
#  'RANGAREDDI' 'WARANGAL' 'DHALAI' 'GOMATI' 'KHOWAI' 'NORTH TRIPURA'
#  'SEPAHIJALA' 'SOUTH TRIPURA' 'UNAKOTI' 'WEST TRIPURA' 'AGRA' 'ALIGARH'
#  'ALLAHABAD' 'AMBEDKAR NAGAR' 'AMETHI' 'AMROHA' 'AURAIYA' 'AZAMGARH'
#  'BAGHPAT' 'BAHRAICH' 'BALLIA' 'BANDA' 'BARABANKI' 'BAREILLY' 'BASTI'
#  'BIJNOR' 'BUDAUN' 'BULANDSHAHR' 'CHANDAULI' 'CHITRAKOOT' 'DEORIA' 'ETAH'
#  'ETAWAH' 'FAIZABAD' 'FARRUKHABAD' 'FATEHPUR' 'FIROZABAD'
#  'GAUTAM BUDDHA NAGAR' 'GHAZIABAD' 'GHAZIPUR' 'GONDA' 'GORAKHPUR' 'HAPUR'
#  'HARDOI' 'HATHRAS' 'JALAUN' 'JAUNPUR' 'JHANSI' 'KANNAUJ' 'KANPUR DEHAT'
#  'KANPUR NAGAR' 'KASGANJ' 'KAUSHAMBI' 'KHERI' 'KUSHI NAGAR' 'LALITPUR'
#  'LUCKNOW' 'MAHARAJGANJ' 'MAHOBA' 'MAINPURI' 'MATHURA' 'MAU' 'MEERUT'
#  'MIRZAPUR' 'MORADABAD' 'MUZAFFARNAGAR' 'PILIBHIT' 'RAE BARELI' 'RAMPUR'
#  'SAHARANPUR' 'SAMBHAL' 'SANT KABEER NAGAR' 'SANT RAVIDAS NAGAR'
#  'SHAHJAHANPUR' 'SHAMLI' 'SHRAVASTI' 'SIDDHARTH NAGAR' 'SITAPUR'
#  'SONBHADRA' 'SULTANPUR' 'UNNAO' 'VARANASI' 'ALMORA' 'BAGESHWAR' 'CHAMOLI'
#  'CHAMPAWAT' 'DEHRADUN' 'HARIDWAR' 'NAINITAL' 'PAURI GARHWAL'
#  'PITHORAGARH' 'RUDRA PRAYAG' 'TEHRI GARHWAL' 'UDAM SINGH NAGAR'
#  'UTTAR KASHI' '24 PARAGANAS NORTH' '24 PARAGANAS SOUTH' 'BANKURA'
#  'BARDHAMAN' 'BIRBHUM' 'COOCHBEHAR' 'DARJEELING' 'DINAJPUR DAKSHIN'
#  'DINAJPUR UTTAR' 'HOOGHLY' 'HOWRAH' 'JALPAIGURI' 'MALDAH'
#  'MEDINIPUR EAST' 'MEDINIPUR WEST' 'MURSHIDABAD' 'NADIA' 'PURULIA']
#
# ============================================================================================
#
# Numbers of districts for which dataset is availabe are:  646

# %% [markdown]
# **Insight:** Names and length of the districts are displayed

# %%
# From 1997 to 2015 years dataset is displayed
years = crops['Crop_Year'].unique()
years
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2010, 1997, 1998, 1999,
#        2007, 2008, 2009, 2011, 2012, 2013, 2014, 2015], dtype=int64)

# %% [markdown]
# **Insight:** Number of years present in the dataset

# %%
# Name of the states are shown
states = crops['State_Name'].unique()
print(states)

print('''
============================================================================================
''')

print("Numbers of states for which dataset is availabe are: ", len(states))
# Out:
# ['Andaman and Nicobar Islands' 'Andhra Pradesh' 'Arunachal Pradesh'
#  'Assam' 'Bihar' 'Chandigarh' 'Chhattisgarh' 'Dadra and Nagar Haveli'
#  'Goa' 'Gujarat' 'Haryana' 'Himachal Pradesh' 'Jammu and Kashmir '
#  'Jharkhand' 'Karnataka' 'Kerala' 'Madhya Pradesh' 'Maharashtra' 'Manipur'
#  'Meghalaya' 'Mizoram' 'Nagaland' 'Odisha' 'Puducherry' 'Punjab'
#  'Rajasthan' 'Sikkim' 'Tamil Nadu' 'Telangana ' 'Tripura' 'Uttar Pradesh'
#  'Uttarakhand' 'West Bengal']
#
# ============================================================================================
#
# Numbers of states for which dataset is availabe are:  33

# %% [markdown]
# **Insight:** Number of States available in the dataset

# %%
# Names of the crop and length is shown
crop = crops['Crop'].unique()
season = crops['Season'].unique()

print(crop)
print(len(crop))
# Out:
# ['Arecanut' 'Other Kharif pulses' 'Rice' 'Banana' 'Cashewnut' 'Coconut '
#  'Dry ginger' 'Sugarcane' 'Sweet potato' 'Tapioca' 'Black pepper'
#  'Dry chillies' 'other oilseeds' 'Turmeric' 'Maize' 'Moong(Green Gram)'
#  'Urad' 'Arhar/Tur' 'Groundnut' 'Sunflower' 'Bajra' 'Castor seed'
#  'Cotton(lint)' 'Horse-gram' 'Jowar' 'Korra' 'Ragi' 'Tobacco' 'Gram'
#  'Wheat' 'Masoor' 'Sesamum' 'Linseed' 'Safflower' 'Onion'
#  'other misc. pulses' 'Samai' 'Small millets' 'Coriander' 'Potato'
#  'Other  Rabi pulses' 'Soyabean' 'Beans & Mutter(Vegetable)' 'Bhindi'
#  'Brinjal' 'Citrus Fruit' 'Cucumber' 'Grapes' 'Mango' 'Orange'
#  'other fibres' 'Other Fresh Fruits' 'Other Vegetables' 'Papaya'
#  'Pome Fruit' 'Tomato' 'Rapeseed &Mustard' 'Mesta' 'Cowpea(Lobia)' 'Lemon'
#  'Pome Granet' 'Sapota' 'Cabbage' 'Peas  (vegetable)' 'Niger seed'
#  'Bottle Gourd' 'Sannhamp' 'Varagu' 'Garlic' 'Ginger' 'Oilseeds total'
#  'Pulses total' 'Jute' 'Peas & beans (Pulses)' 'Blackgram' 'Paddy'
#  'Pineapple' 'Barley' 'Khesari' 'Guar seed' 'Moth'
#  'Other Cereals & Millets' 'Cond-spcs other' 'Turnip' 'Carrot' 'Redish'
#  'Arcanut (Processed)' 'Atcanut (Raw)' 'Cashewnut Processed'
#  'Cashewnut Raw' 'Cardamom' 'Rubber' 'Bitter Gourd' 'Drum Stick'
#  'Jack Fruit' 'Snak Guard' 'Pump Kin' 'Tea' 'Coffee' 'Cauliflower'
#  'Other Citrus Fruit' 'Water Melon' 'Total foodgrain' 'Kapas' 'Colocosia'
#  'Lentil' 'Bean' 'Jobster' 'Perilla' 'Rajmash Kholar' 'Ricebean (nagadal)'
#  'Ash Gourd' 'Beet Root' 'Lab-Lab' 'Ribed Guard' 'Yam' 'Apple' 'Peach'
#  'Pear' 'Plums' 'Litchi' 'Ber' 'Other Dry Fruit' 'Jute & mesta']
# 124

# %% [markdown]
# **Insight:** Number of Crops available in the dataset

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Missing Values/Null Values

# %%
# It is used to identify and count missing values (NaNs) in a DataFrame
crops.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %% [markdown]
# **Insight**: Here we used isnull().sum() to identify and count missing values (NaNs) in a DataFrame

# %%
# Replace NaNs in 'Production' column with 0
crops['Production'] = crops['Production'].fillna(0)

# %% [markdown]
# **Insight**: Here we replace all NaN values with 0. (for Production)

# %%
# Gives the a concise summary of a DataFrame.
crops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     246091 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %% [markdown]
# **Insight:** After replacing NaN values with 0 again we use info() to get concise summary of our dataset.

# %% [markdown]
# # Duplicate Values

# %%
# to check for duplicate rows in a DataFrame
crops.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Insight:** Here we can see there are 0 duplicates values in our dataframe.

# %%
# Prints the shape i.e. the row size by column size of the dataset
crops.shape
# Out:
# (246091, 7)

# %% [markdown]
# **Insight:** Here we can see there are 246091 rows and 7 columns.

# %%
# To print the column names present in the dataset.
crops.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area',
#        'Production'],
#       dtype='object')

# %% [markdown]
# **Insight:** Again we print the column name

# %%
# checking the final shape of the dataset
print(f' final shape of the dataset is {crops.shape}')
# Out:
#  final shape of the dataset is (246091, 7)

# %% [markdown]
# **Insight:** In final shape there are 246091 rows and 7 columns

# %% [markdown]
# # Check Unique Values For Each Varaiable

# %%
# Check Unique Values for each variable.
# creating a series consisting every column name of the dataset and it's value.                                                       
# used for loop to iterate over every column in the dataset
pd.Series({col:crops[col].unique() for col in crops})
# Out:
# State_Name       [Andaman and Nicobar Islands, Andhra Pradesh, ...
# District_Name    [NICOBARS, NORTH AND MIDDLE ANDAMAN, SOUTH AND...
# Crop_Year        [2000, 2001, 2002, 2003, 2004, 2005, 2006, 201...
# Season           [Kharif     , Whole Year , Autumn     , Rabi  ...
# Crop             [Arecanut, Other Kharif pulses, Rice, Banana, ...
# Area             [1254.0, 2.0, 102.0, 176.0, 720.0, 18168.0, 36...
# Production       [2000.0, 1.0, 321.0, 641.0, 165.0, 65100000.0,...
# dtype: object

# %% [markdown]
# **Insight:** Here we checked all unique values from our dataframe

# %%
# Gives the overall info of the dataframe object
crops.describe()
# Out:
#            Crop_Year          Area    Production
# count  246091.000000  2.460910e+05  2.460910e+05
# mean     2005.643018  1.200282e+04  5.736744e+05
# std         4.952164  5.052340e+04  1.693614e+07
# min      1997.000000  4.000000e-02  0.000000e+00
# 25%      2002.000000  8.000000e+01  7.700000e+01
# 50%      2006.000000  5.820000e+02  6.910000e+02
# 75%      2010.000000  4.392000e+03  6.769000e+03
# max      2015.000000  8.580100e+06  1.250800e+09

# %% [markdown]
# **Insight:** Describe() give the overall information of our dataset object.

# %%
# non-numeric value description >> "O" stands for Objective
crops.describe(include = 'O').T
# Out:
#                 count unique            top   freq
# State_Name     246091     33  Uttar Pradesh  33306
# District_Name  246091    646        BIJAPUR    945
# Season         246091      6    Kharif       95951
# Crop           246091    124           Rice  15104

# %% [markdown]
# **Insight:**
# In previous describe() we got only numeric values so get string value we used describe(include = 'O').T
# In output we can see non-numeric values.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Chart 1

# %%
# Assuming 'crops' is your DataFrame
new_df = crops.groupby('Crop')['Production'].sum().reset_index()
sorted_prod = new_df.sort_values(by='Production', ascending=False)

# Ensure coconut is included, and then select the top 5 crops
top_crops = sorted_prod.head(5)  # Get the top 5 crops

# Check if coconut is in the top crops; if not, include it
if 'Coconut' not in top_crops['Crop'].values:
    # If coconut is not in the top 5, add it separately
    coconut_data = sorted_prod[sorted_prod['Crop'] == 'Coconut']
    if not coconut_data.empty:
        top_crops = pd.concat([top_crops, coconut_data]).drop_duplicates().head(5)

# Prepare data for bar chart
crop_names = top_crops['Crop']
production_values = top_crops['Production']

# Create bar plot
plt.figure(figsize=(10, 6))
plt.bar(crop_names, production_values, color='purple')
plt.xlabel('Crops')
plt.ylabel('Total Production')
plt.title('Crop Production Distribution')
plt.xticks(rotation=45)
plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()

# %% [markdown]
# **Insight:** Coconut production is the highest

# %% [markdown]
# ## Chart 2

# %%
# Assuming 'crops' is your DataFrame
new_df = crops.groupby('Crop')['Production'].sum().reset_index()
sorted_prod = new_df.sort_values(by='Production', ascending=False)

# Select crops for the pie chart 
plot_pie = sorted_prod[5:15]

# Prepare data for pie chart
crop_names = plot_pie['Crop']
production_values = plot_pie['Production']

# Create pie chart
plt.figure(figsize=(8, 10))
plt.pie(production_values, labels=crop_names, autopct='%1.1f%%', startangle=140)
plt.title('Crop Production Distribution (Excluding Coconut, Sugarcane, Rice, Wheat, Potato)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# **Insight:** Production of top 10 crops excluding top 5 crops Coconut, Sugarcane, Rice, Wheat, Potato are given

# %% [markdown]
# ## Chart 3

# %%
# Assuming 'crops' is your DataFrame
state_production = crops.groupby('State_Name')['Production'].sum()

sorted_states_desc = state_production.sort_values(ascending=False)

# Get the top 15 states
top_15_states_desc = sorted_states_desc.head(15)

# Create bar plot including the top state
plt.figure(figsize=(12, 6))
plt.bar(top_15_states_desc.index, top_15_states_desc.values, color='blue')
plt.xlabel('States')
plt.ylabel('Production')
plt.title('Top 15 States by Production')
plt.xticks(rotation=90)
plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()

# %% [markdown]
# **Insight:** Top 15 States Production of Crops

# %% [markdown]
# ## Chart 4

# %%
# Assuming 'crops' is your DataFrame
state_production = crops.groupby('State_Name')['Production'].sum()

# Sort states by production in ascending order
sorted_states_asc = state_production.sort_values(ascending=True)

# Get the bottom 15 states
bottom_15_states_asc = sorted_states_asc.head(15)

# Create bar plot for the bottom 15 states
plt.figure(figsize=(12, 6))
plt.bar(bottom_15_states_asc.index, bottom_15_states_asc.values, color='darkorange')
plt.xlabel('States')
plt.ylabel('Production')
plt.title('Bottom 15 States by Production')
plt.xticks(rotation=90)
plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()

# %% [markdown]
# **Insight:** 15 Lowest Crop Production in States

# %% [markdown]
# ## Chart 5

# %%
# Group and sum the production by district
district_production = crops.groupby('District_Name')['Production'].sum()

# Sort the districts in descending order
sorted_districts_desc = district_production.sort_values(ascending=False)

# Get the top 21 districts, including number 1
top_21_districts_desc = sorted_districts_desc.head(21)

# Create the bar plot
plt.figure(figsize=(12, 6))
plt.bar(top_21_districts_desc.index, top_21_districts_desc.values)
plt.xlabel('Districts')
plt.ylabel('Production')
plt.title('Top 21 Districts by Production')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Insight:** Top 21 District Producing Crop

# %% [markdown]
# ## Chart 6

# %%
# Prints the number of rows and columns in bajra production
bajra = crops[crops['Crop'] == 'Bajra']
bajra
# Out:
#             State_Name District_Name  Crop_Year       Season   Crop    Area  \
# 204     Andhra Pradesh     ANANTAPUR       1997  Kharif       Bajra  1400.0
# 232     Andhra Pradesh     ANANTAPUR       1998  Kharif       Bajra  2600.0
# 258     Andhra Pradesh     ANANTAPUR       1999  Kharif       Bajra  1635.0
# 271     Andhra Pradesh     ANANTAPUR       1999  Rabi         Bajra    99.0
# 289     Andhra Pradesh     ANANTAPUR       2000  Kharif       Bajra  2477.0
# ...                ...           ...        ...          ...    ...     ...
# 245929     West Bengal       PURULIA       2010  Kharif       Bajra    62.0
# 245961     West Bengal       PURULIA       2011  Kharif       Bajra    59.0
# 245994     West Bengal       PURULIA       2012  Kharif       Bajra    56.0
# 246024     West Bengal       PURULIA       2013  Kharif       Bajra    34.0
# 246061     West Bengal       PURULIA       2014  Kharif       Bajra    49.0
#
#         Production
# 204          500.0
# 232         1900.0
# 258          889.0
# 271           54.0
# 289         1449.0
# ...            ...
# 245929        22.0
# 245961        22.0
# 245994        20.0
# 246024        14.0
# 246061        19.0
#
# [5427 rows x 7 columns]

# %% [markdown]
# **Insight:** The production of Bajra is given in 5427 rows and 7 columns

# %%
# Example DataFrame (replace with your actual DataFrame)
# bajra = pd.DataFrame({
#     'Season': ['Kharif', 'Rabi', 'Whole Year' 'Summer', 'Autumn', 'Winter'],
#     'Production': [100, 200, 150, 250, ...]
# })

# Create the barplot
plt.figure(figsize=(10, 6))
sns.barplot(x="Season", y="Production", data=bajra, errorbar=None).set_title('Production Of Bajra in the Season')  # Specify x, y, and data explicitly

# Rotate x-axis labels if needed
plt.xticks

plt.show()

# %% [markdown]
# **Insight:** The production of bajra in season kharif, rabi, whole year, summer is analyzed

# %% [markdown]
# ## Chart 7

# %%
# Create the barplot with adjusted width for more space between bars
plt.figure(figsize=(12, 8))
sns.barplot(x="Crop_Year", y="Production", data=bajra, errorbar=None, width=0.7).set_title('Production Of Bajra in the Crop Year')  # Adjust the width here

# Rotate x-axis labels if needed
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# **Insight:** from 1997 to 2014 production of bajra is shown

# %% [markdown]
# ## Chart 8

# %%
# Prints the number of rows and columns present in Tomato
tomato = crops[crops['Crop'] == 'Tomato']
tomato
# Out:
#             State_Name District_Name  Crop_Year       Season    Crop     Area  \
# 437     Andhra Pradesh     ANANTAPUR       2002  Whole Year   Tomato   3356.0
# 492     Andhra Pradesh     ANANTAPUR       2003  Whole Year   Tomato   2827.0
# 827     Andhra Pradesh     ANANTAPUR       2012  Kharif       Tomato   2552.0
# 852     Andhra Pradesh     ANANTAPUR       2012  Rabi         Tomato   1395.0
# 888     Andhra Pradesh     ANANTAPUR       2013  Kharif       Tomato   2991.0
# ...                ...           ...        ...          ...     ...      ...
# 195235      Telangana      NIZAMABAD       2003  Whole Year   Tomato   1716.0
# 195834      Telangana     RANGAREDDI       2002  Whole Year   Tomato  10468.0
# 195894      Telangana     RANGAREDDI       2003  Whole Year   Tomato   8975.0
# 196484      Telangana       WARANGAL       2002  Whole Year   Tomato   1688.0
# 196537      Telangana       WARANGAL       2003  Whole Year   Tomato   1719.0
#
#         Production
# 437        16627.0
# 492        17509.0
# 827        38561.0
# 852        31096.0
# 888        88620.0
# ...            ...
# 195235     11319.0
# 195834     51786.0
# 195894     72659.0
# 196484      9011.0
# 196537     11518.0
#
# [368 rows x 7 columns]

# %% [markdown]
# **Insight:** The production of Tomato is described through 368 rows and 7 columns

# %%
# Example DataFrame (replace with your actual DataFrame)
# tomato = pd.DataFrame({
#     'Season': ['Kharif', 'Rabi', 'Whole Year' 'Summer', 'Autumn', 'Winter'],
#     'Production': [100, 200, 150, 250, ...]
# })

# Create the barplot
plt.figure(figsize=(10, 6))
sns.barplot(x="Season", y="Production", data=tomato, errorbar=None).set_title('Production Of Tomato in the Season')  # Specify x, y, and data explicitly

# Rotate x-axis labels if needed
plt.xticks

plt.show()

# %% [markdown]
# **Insight:** The production of Tomato in season Whole Year, Kharif, Rabi is analyzed

# %% [markdown]
# ## Chart 9

# %%
# Create the barplot with adjusted width for more space between bars
plt.figure(figsize=(15, 10))
sns.barplot(x="Crop_Year", y="Production", data=tomato, errorbar=None, width=0.6).set_title('Production Of Tomato in the Crop Year')  # Adjust width for spacing

# Rotate x-axis labels if needed
plt.xticks

# Display the plot
plt.show()

# %% [markdown]
# **Insight:** In 2002, 2003, 2012, 2013 and 2014 tomatoes are produced

# %% [markdown]
# ## Chart 10

# %%
# Filter data for Andhra Pradesh
df1 = crops
kerala_data = df1[df1['State_Name'] == 'Andhra Pradesh']

# Group and sum the production by crop
crop_production = kerala_data.groupby('Crop')['Production'].sum().reset_index()

# Sort the crops by production
prominent_crops = crop_production.sort_values('Production', ascending=False)

# Get the top 6 crops, including the first
top_6_crops = prominent_crops.head(6)  # Use head(6) instead of iloc[1:7]

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(top_6_crops['Crop'], top_6_crops['Production'], color = 'brown')
plt.xlabel('Crop')
plt.ylabel('Production')
plt.title('Top 6 Prominent Crops in Andhra Pradesh')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:** Top 6 Prominent Crops in Andhra Pradesh

# %% [markdown]
# ## Chart 11

# %%
# Filter data for Uttar Pradesh
df1 = crops
kerala_data = df1[df1['State_Name'] == 'Uttar Pradesh']

# Group and sum the production by crop
crop_production = kerala_data.groupby('Crop')['Production'].sum().reset_index()

# Sort the crops by production
prominent_crops = crop_production.sort_values('Production', ascending=False)

# Get the top 6 crops, including the first
top_6_crops = prominent_crops.head(6)  # Use head(6) instead of iloc[1:7]

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(top_6_crops['Crop'], top_6_crops['Production'])
plt.xlabel('Crop')
plt.ylabel('Production')
plt.title('Top 6 Prominent Crops in Uttar Pradesh')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:** Top 6 Prominent Crops in Uttar Pradesh

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **In the Chart 1 bar chart we can view the top 5 production of crops in india which are Coconut, Sugarcane, Rice Wheat and Potato. Among these 5 crops Coconut has the highest production.**
#
# **In the Chart 2 pie chart Production of top 10 crops excluding top 5 crops Coconut, Sugarcane, Rice, Wheat, Potato are given.**
#
# **In the Chart 3 top 15 states producing crops in which Kerala has the highest production.**
#
# **In the Chart 4 bottom 15 states producing crops in which Chandigarh has the lowest production.**
#
# **In the Chart 5 top 21 districts producing crops in which Kerala has the highest production.**
#
# **In the Chart 6th and 7th the production of Bajra in season kharif, rabi, whole year, summer is analyzed and the years in which bajra was produced is analyzed.**
#
# **In the Chart 8th and 9th the production of Tomato in season kharif, rabi, whole year is analyzed and the years in which bajra was produced is analyzed.**
#
# **In the Chart 10th and 11th the bar chart plots the top 6 prominent crops in Andhra Pradesh and the top 6 prominent crops in Uttar Pradesh.**
#
# **The analysis of crop production in India, based on a dataset of state name, district name, crop year, season, area, and production, highlights significant regional disparities and seasonal trends.**
#
# **Key insights include the need for improved land use efficiency, targeted crop selection, and sustainable practices to enhance productivity.**
#
# **These findings can inform policymakers and stakeholders in developing strategies to ensure food security and optimize agricultural output.**

# %% [markdown]
# ## Recommendation

# %% [markdown]
# **Promote Sustainable Practices: Encourage the adoption of sustainable agricultural methods to improve soil health and reduce environmental impact.**
#
# **Optimize Crop Selection: Implement region-specific crop selection based on local soil and climate conditions to enhance yields.**
#
# **Enhance Irrigation Efficiency: Invest in water management systems to improve irrigation practices and address water scarcity.**
#
# **Strengthen Infrastructure: Improve storage and transportation infrastructure to reduce post-harvest losses and improve market access.**
#
# **Provide Farmer Training: Offer training programs on modern farming techniques and technology to boost productivity and resilience.**
#
# **Data-Driven Policies: Utilize data analytics to inform policies that address regional disparities and support underperforming areas.**
